# %% [markdown]
# # Welcome to BankCraft
# ====================

# %%
from bankcraft.bankcraftmodel import BankCraftModel
from bankcraft.utils.visualization import Visualization

model = BankCraftModel()

model.run(365)

vis = Visualization(model)
vis.grid_plot()
# Out:
# interactive(children=(SelectionSlider(description='Time:', layout=Layout(width='500px'), options=('2023-01-01 …
